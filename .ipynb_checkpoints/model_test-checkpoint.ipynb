# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

import warnings
warnings.filterwarnings('ignore')

import matplotlib.dates as mdates
from mpl_finance import candlestick_ohlc
# Out:
# /Users/michaelyang/.conda/envs/CryptoCurrency_Project/lib/python2.7/site-packages/pandas/_libs/__init__.py:4: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from .tslib import iNaT, NaT, Timestamp, Timedelta, OutOfBoundsDatetime
# /Users/michaelyang/.conda/envs/CryptoCurrency_Project/lib/python2.7/site-packages/pandas/__init__.py:26: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import (hashtable as _hashtable,
# /Users/michaelyang/.conda/envs/CryptoCurrency_Project/lib/python2.7/site-packages/pandas/core/dtypes/common.py:6: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import algos, lib
# /Users/michaelyang/.conda/envs/CryptoCurrency_Project/lib/python2.7/site-packages/pandas/core/util/hashing.py:7: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import hashing, tslib
# /Users/michaelyang/.conda/envs/CryptoCurrency_Project/lib/python2.7/site-packages/pandas/core/indexes/base.py:6: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import (lib, index as libindex, tslib as libts,
# /Users/michaelyang/.conda/envs/CryptoCurrency_Project/lib/python2.7/site-packages/pandas/core/tools/datetimes.py:6: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs.tslibs.strptime import array_strptime
# /Users/michaelyang/.conda/envs/CryptoCurrency_Project/lib/python2.7/site-packages/pandas/tseries/frequencies.py:24: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs.tslibs.frequencies import (  # noqa
# /Users/michaelyang/.conda/envs/CryptoCurrency_Project/lib/python2.7/site-packages/pandas/core/indexes/datetimelike.py:28: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs.period import Period
# /Users/michaelyang/.conda/envs/CryptoCurrency_Project/lib/python2.7/site-packages/pandas/core/sparse/array.py:33: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   import pandas._libs.sparse as splib
# /Users/michaelyang/.conda/envs/CryptoCurrency_Project/lib/python2.7/site-packages/pandas/core/window.py:36: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   import pandas._libs.window as _window
# /Users/michaelyang/.conda/envs/CryptoCurrency_Project/lib/python2.7/site-packages/pandas/core/groupby.py:68: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import lib, groupby as libgroupby, Timestamp, NaT, iNaT
# /Users/michaelyang/.conda/envs/CryptoCurrency_Project/lib/python2.7/site-packages/pandas/core/reshape/reshape.py:31: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import algos as _algos, reshape as _reshape
# /Users/michaelyang/.conda/envs/CryptoCurrency_Project/lib/python2.7/site-packages/pandas/io/parsers.py:45: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   import pandas._libs.parsers as parsers
# /Users/michaelyang/.conda/envs/CryptoCurrency_Project/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# load BTC data

import json
import requests

apiKey = 'bf7c04a024b244dea99e95798fa8e102b7c9738c0933795253c2c8f39f2d160c'

url = 'https://min-api.cryptocompare.com/data/histoday'

payload = {
    "api_key": apiKey,
    "fsym": "BTC",
    "tsym": "USD",
    "limit": 2000
}

res_BTC = requests.get(url, params=payload)
hist_BTC = pd.DataFrame(json.loads(res_BTC.content)['Data'])
hist_BTC = hist_BTC.set_index('time')
hist_BTC.index = pd.to_datetime(hist_BTC.index, unit='s')

# %%
# get price change log return
target_col = 'close'
s_test = hist_BTC[target_col]
log_return = np.log(s_test/s_test.shift())
hist_BTC['price change'] = log_return

# feature extraction from OHLC
'''close/open: since cryprocurrencies are continuously trading, this is the same as price change above
close price of t-1 is the same as open price of t'''
#hist_BTC['close/open'] = np.log(hist_BTC['close']/hist_BTC['open'])
'''high/open'''
hist_BTC['high/open'] = np.log(hist_BTC['high']/hist_BTC['open'])
'''low/open'''
hist_BTC['low/open'] = np.log(hist_BTC['low']/hist_BTC['open'])
'''close/high'''
hist_BTC['close/high'] = np.log(hist_BTC['close']/hist_BTC['high'])
'''close/low'''
hist_BTC['close/low'] = np.log(hist_BTC['close']/hist_BTC['low'])
hist_BTC = hist_BTC.drop(['close','high','low','open','volumefrom'],axis=1)
hist_BTC.rename(columns = {'volumeto':'volumn'},inplace=True)
hist_BTC = hist_BTC.dropna()

# %%
hist_BTC.head()
# Out:
#                 volumn  price change  high/open  low/open  close/high  \
# time
# 2013-10-12  1559472.71      0.019719   0.020838 -0.005081   -0.001119
# 2013-10-13  2342049.46      0.031956   0.032770 -0.009775   -0.000813
# 2013-10-14  4512823.60      0.025696   0.040906 -0.010219   -0.015210
# 2013-10-15  2416464.87      0.043437   0.043501 -0.004967   -0.000063
# 2013-10-16  6636228.59     -0.033904   0.030524 -0.091963   -0.064428
#
#             close/low
# time
# 2013-10-12   0.024799
# 2013-10-13   0.041732
# 2013-10-14   0.035915
# 2013-10-15   0.048404
# 2013-10-16   0.058060

# %%
# news data

url = 'https://min-api.cryptocompare.com/data/v2/news/'

payload = {
    "api_key": apiKey,
    "lang": "EN",
    
}

res_BTC = requests.get(url, params=payload)
hist_BTC = pd.DataFrame(json.loads(res_BTC.content)['Data'])
#hist_BTC = hist_BTC.set_index('time')
#hist_BTC.index = pd.to_datetime(hist_BTC.index, unit='s')

# %%
hist_BTC.head()
# Out:
#                                                 body  \
# 0  Bitcoin Could See Another 20% Leg Up From Here...
# 1  Forks Bitcoin Cash (BCH) and Bitcoin SV (BSV) ...
# 2  2018 was a bad year for crypto miners as a lot...
# 3  Bitcoin [BTC], the undoubted king of the crypt...
# 4  After reaching ATH in 2017, Bitcoin started to...
#
#                    categories downvotes  \
# 0      BTC|Trading|Market|ETH         0
# 1                 BTC|Trading         0
# 2               Mining|Market         0
# 3  BTC|Market|Altcoin|LTC|XMR         0
# 4                     BTC|ETH         0
#
#                                      guid       id  \
# 0  https://ethereumworldnews.com/?p=38681  1008893
# 1       https://cryptoslate.com/?p=100649  1008892
# 2            http://coingape.com/?p=27648  1008891
# 3          https://ambcrypto.com/?p=79054  1008890
# 4  https://ethereumworldnews.com/?p=38687  1008889
#
#                                             imageurl lang  published_on  \
# 0  https://images.cryptocompare.com/news/ethereum...   EN    1554257289
# 1  https://images.cryptocompare.com/news/cryptosl...   EN    1554255856
# 2  https://images.cryptocompare.com/news/coingape...   EN    1554255081
# 3  https://images.cryptocompare.com/news/ambcrypt...   EN    1554255000
# 4  https://images.cryptocompare.com/news/ethereum...   EN    1554254346
#
#               source                                        source_info  \
# 0  ethereumworldnews  {u'lang': u'EN', u'name': u'Ethereum World New...
# 1        cryptoslate  {u'lang': u'EN', u'name': u'CryptoSlate', u'im...
# 2           coingape  {u'lang': u'EN', u'name': u'CoinGape', u'img':...
# 3          ambcrypto  {u'lang': u'EN', u'name': u'AMB Crypto', u'img...
# 4  ethereumworldnews  {u'lang': u'EN', u'name': u'Ethereum World New...
#
#                                                 tags  \
# 0  Bitcoin News|Crypto Analysis|Analysis|bitcoin|...
# 1  Bitcoin|Bitcoin Cash|Price Analysis|Price Watc...
# 2           Bitcoin News|Bitfarms|crypto mining|loss
# 3  Altcoins|Analysis|Bitcoin|News|Social|Cardano|...
# 4  Uncategorized|Bitcoin (BTC)|Bitcoin (BTC) Bull...
#
#                                                title upvotes  \
# 0  CNBC Crazy Bullish On Crypto, Resident Fund Ma...       0
# 1  BTC forks post astronomical 24 hour gains, Bit...       0
# 2  Crypto Miners Struggle Continues as Israeli Cr...       0
# 3  Bitcoin for Altcoin: Top cryptocurrencies ride...       0
# 4  John McAfee Says “Told ya” To The Whole World ...       0
#
#                                                  url
# 0  https://ethereumworldnews.com/cnbc-crazy-bulli...
# 1  https://cryptoslate.com/btc-forks-post-astrono...
# 2  https://coingape.com/israeli-crypto-mining-fir...
# 3  https://ambcrypto.com/bitcoin-for-altcoin-top-...
# 4  https://ethereumworldnews.com/john-mcafee-says...
